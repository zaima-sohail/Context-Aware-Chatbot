# %%
! pip install langchain
! pip install langchain-community

! pip install faiss-cpu
! pip install sentence-transformers
! pip install pypdf
! pip install tiktoken
! pip install streamlit
! pip install python-dotenv
# Out:
# ...
# WARNING: Ignoring invalid distribution ~etuptools (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etuptools (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etuptools (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
! pip install -U langchain langchain-google-genai langchain-community faiss-cpu sentence-transformers pypdf streamlit python-dotenv
# Out:
# ...
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.4 MB 686.5 kB/s eta 0:00:24
#    - -------------------------------------- 0.5/16.4 MB 686.5 kB/s eta 0:00:24
#    - -------------------------------------- 0.8/16.4 MB 687.9 kB/s eta 0:00:23
#    - -------------------------------------- 0.8/16.4 MB 687.9 kB/s eta 0:00:23
# ...

# %%
import os

from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings

from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain

from langchain_google_genai import ChatGoogleGenerativeAI
# Out:
# C:\Users\zaima\AppData\Local\Temp\ipykernel_15828\1277260282.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 import os
#       2
#       3 from langchain_community.document_loaders import TextLoader
# ----> 4 from langchain.text_splitter import RecursiveCharacterTextSplitter
#       5
#       6 from langchain_community.vectorstores import FAISS
#       7 from langchain_community.embeddings import HuggingFaceEmbeddings
#
# ModuleNotFoundError: No module named 'langchain.text_splitter'

# %%
! pip show langchain
# Out:
# Name: langchain
# Version: 1.3.13
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# WARNING: Ignoring invalid distribution ~etuptools (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)

# %%
! pip install -U langchain
! pip install -U langchain-community
! pip install -U langchain-google-genai
! pip install -U langchain-text-splitters
! pip install -U faiss-cpu
! pip install -U sentence-transformers
# Out:
# ...
# WARNING: Ignoring invalid distribution ~etuptools (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etuptools (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etuptools (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\zaima\AppData\Local\Programs\Python\Python314\python.exe

# %%
! pip show langchain
! pip show langchain-core
! pip show langchain-community
! pip show langchain-google-genai
# Out:
# Name: langchain
# Version: 1.3.13
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# WARNING: Ignoring invalid distribution ~etuptools (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# Name: langchain-core
# Version: 1.4.9
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages
# Requires: jsonpatch, langchain-protocol, langsmith, packaging, pydantic, pyyaml, tenacity, typing-extensions, uuid-utils
# ...

# %%
! pip install -U langchain langchain-community langchain-google-genai langchain-text-splitters faiss-cpu sentence-transformers pypdf
# Out:
# ...
# WARNING: Ignoring invalid distribution ~etuptools (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etuptools (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etuptools (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (C:\Users\zaima\AppData\Local\Programs\Python\Python314\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
